# %%
import pandas as pd
import numpy as np

animes = pd.Series(["Phantom Blood","Battle Tendency","Stardust Crusaders","Diamont is Unbreakable","Golden Wind","Stone Ocean"])

animes[5]

personajes = pd.DataFrame({
  'Nombre' : ['Jonathan','Joseph','Jotaro','Josuke','Giorno','Jolyne'],
  'Genero' : ['M','M','M','M','M','F'],
  'Stand' : ['The passione','Hermit Purple','Star Platinum','Crazy Diamont','Golden Experience','Stone Free']
})

personajes.head(6)
# Out:
#      Nombre Genero              Stand
# 0  Jonathan      M       The passione
# 1    Joseph      M      Hermit Purple
# 2    Jotaro      M      Star Platinum
# 3    Josuke      M      Crazy Diamont
# 4    Giorno      M  Golden Experience
# 5    Jolyne      F         Stone Free
