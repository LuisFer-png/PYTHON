# %%
import pandas as pd
import numpy as np

pokemon_db = pd.read_csv("Pokemon.csv")

pokemon_db.head(50)
# Out:
#      #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0    1                  Bulbasaur     Grass  Poison    318   45      49
# 1    2                    Ivysaur     Grass  Poison    405   60      62
# 2    3                   Venusaur     Grass  Poison    525   80      82
# 3    3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4    4                 Charmander      Fire     NaN    309   39      52
# 5    5                 Charmeleon      Fire     NaN    405   58      64
# 6    6                  Charizard      Fire  Flying    534   78      84
# 7    6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8    6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9    7                   Squirtle     Water     NaN    314   44      48
# 10   8                  Wartortle     Water     NaN    405   59      63
# 11   9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
pokemon_db[['Name','HP','Attack']]
# Out:
#                       Name  HP  Attack
# 0                Bulbasaur  45      49
# 1                  Ivysaur  60      62
# 2                 Venusaur  80      82
# 3    VenusaurMega Venusaur  80     100
# 4               Charmander  39      52
# ..                     ...  ..     ...
# 795                Diancie  50     100
# 796    DiancieMega Diancie  50     160
# 797    HoopaHoopa Confined  80     110
# 798     HoopaHoopa Unbound  80     160
# 799              Volcanion  80     110
#
# [800 rows x 3 columns]

# %%
pokemon_db[['Name','Type 1','Speed']]
# Out:
#                       Name   Type 1  Speed
# 0                Bulbasaur    Grass     45
# 1                  Ivysaur    Grass     60
# 2                 Venusaur    Grass     80
# 3    VenusaurMega Venusaur    Grass     80
# 4               Charmander     Fire     65
# ..                     ...      ...    ...
# 795                Diancie     Rock     50
# 796    DiancieMega Diancie     Rock    110
# 797    HoopaHoopa Confined  Psychic     70
# 798     HoopaHoopa Unbound  Psychic     80
# 799              Volcanion     Fire     70
#
# [800 rows x 3 columns]

# %%
pokemon_db.isnull().sum()
pokemon_db["HP"].mean()
# Out:
# np.float64(69.25875)

# %%
pokemon_db.groupby('Type 1')['Attack'].mean().sort_values(ascending=False)
# Out:
# Type 1
# Dragon      112.125000
# Fighting     96.777778
# Ground       95.750000
# Rock         92.863636
# Steel        92.703704
# Dark         88.387097
# Fire         84.769231
# Flying       78.750000
# Poison       74.678571
# Water        74.151786
# Ghost        73.781250
# Normal       73.469388
# Grass        73.214286
# Ice          72.750000
# Psychic      71.456140
# Bug          70.971014
# Electric     69.090909
# Fairy        61.529412
# Name: Attack, dtype: float64

# %%
pokemon_db.loc[64, ["Type 1","Type 2","Name"]]
pokemon_db.iloc[50:60, 0:6]
# Out:
#      #       Name  Type 1  Type 2  Total  HP
# 50  45  Vileplume   Grass  Poison    490  75
# 51  46      Paras     Bug   Grass    285  35
# 52  47   Parasect     Bug   Grass    405  60
# 53  48    Venonat     Bug  Poison    305  60
# 54  49   Venomoth     Bug  Poison    450  70
# 55  50    Diglett  Ground     NaN    265  10
# 56  51    Dugtrio  Ground     NaN    405  35
# 57  52     Meowth  Normal     NaN    290  40
# 58  53    Persian  Normal     NaN    440  65
# 59  54    Psyduck   Water     NaN    320  50

# %%
pokemon_db[pokemon_db["Type 1"] == 'Electric']
# Out:
#        #                      Name    Type 1  Type 2  Total  HP  Attack  \
# 30    25                   Pikachu  Electric     NaN    320  35      55
# 31    26                    Raichu  Electric     NaN    485  60      90
# 88    81                 Magnemite  Electric   Steel    325  25      35
# 89    82                  Magneton  Electric   Steel    465  50      60
# 108  100                   Voltorb  Electric     NaN    330  40      30
# 109  101                 Electrode  Electric     NaN    480  60      50
# 134  125                Electabuzz  Electric     NaN    490  65      83
# 146  135                   Jolteon  Electric     NaN    525  65      65
# 157  145                    Zapdos  Electric  Flying    580  90      90
# 186  172                     Pichu  Electric     NaN    205  20      40
# 193  179                    Mareep  Electric     NaN    280  55      40
# 194  180                   Flaaffy  Electric     NaN    365  70      55
# ...

# %%
pokemon_db[(pokemon_db["Speed"] > 100) & (pokemon_db["Type 1"] == 'Water')| (pokemon_db["Type 2"] == 'Water')]
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 130  121                Starmie     Water   Psychic    520   60      75
# 149  138                Omanyte      Rock     Water    355   35      40
# 150  139                Omastar      Rock     Water    495   70      60
# 151  140                 Kabuto      Rock     Water    355   30      80
# 152  141               Kabutops      Rock     Water    495   60     115
# 307  283                Surskit       Bug     Water    269   40      30
# 349  319  SharpedoMega Sharpedo     Water      Dark    560   70     140
# 398  363                 Spheal       Ice     Water    290   70      40
# 399  364                 Sealeo       Ice     Water    410   90      60
# 400  365                Walrein       Ice     Water    530  110      80
# 445  400                Bibarel    Normal     Water    410   79      85
# 466  419               Floatzel     Water       NaN    495   85     105
# ...
